# %%
import json, time
from collections import deque
import paho.mqtt.client as mqtt

PI_IP = "192.168.68.110"
TOPIC = "imu/raw"

buffer = deque(maxlen=5000)
msg_count = 0
client = None

# %%
def on_connect(client, userdata, flags, reason_code, properties=None):
    print("✅ Connected:", reason_code)
    client.subscribe(TOPIC, qos=0)
    print("📡 Subscribed to:", TOPIC)

def on_message(client, userdata, msg):
    global msg_count
    payload = json.loads(msg.payload.decode("utf-8"))
    buffer.append(payload)
    msg_count += 1

global client
client = mqtt.Client(callback_api_version=mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message
client.connect(PI_IP, 1883, 60)
client.loop_start()

print("Listening…")
# Out:
# Listening…
# ✅ Connected: Success
# 📡 Subscribed to: imu/raw

# %%
print("msgs:", msg_count)
if msg_count > 0:
    print("latest:", buffer[-1])
# Out:
# msgs: 1623
# latest: {'timestamp_ms': 1767449522426, 'timestamp_iso_utc': '2026-01-03T14:12:02.426+00:00', 'host': 'rashberrypi123', 'dt_s': 0.02, 'accel_g': {'x': -0.06467094272375107, 'y': -0.1051744893193245, 'z': 1.0028126239776611}, 'gyro_dps': {'x': -0.0018911100924015045, 'y': 0.002182943746447563, 'z': -0.0017917369259521365}}
